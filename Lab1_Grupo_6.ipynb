# %% [markdown]
# <a href="https://colab.research.google.com/github/wilmansh/Lab2/blob/main/Lab1_Grupo_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the scalar function
def scalar_function(x, y):
    return x**2 + y**2

# Create a grid of x and y values
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Calculate the function values
Z = scalar_function(X, Y)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z)

# Show the plot
plt.show()

from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/My Drive/Colab Notebooks
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks
